# %% [markdown]
# <a href="https://colab.research.google.com/github/sahiltalokar/PRODIGY_GA_02/blob/main/ImageGenerationOutput.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install required libraries
# !pip install --upgrade diffusers transformers accelerate safetensors

# Step 2: Import libraries
from diffusers import StableDiffusionPipeline
import torch
from IPython.display import display

# Step 3: Setup device
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

# Step 4: Load Stable Diffusion model
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16 if device == "cuda" else torch.float32
).to(device)

# Step 5: Generate an image
prompt = "A mythical dragon flying around a big castle"
image = pipe(prompt, guidance_scale=7.5).images[0]

# Step 6: Display and save
display(image)
image.save("fantasy_landscape.png")
print("Image saved as fantasy_landscape.png")
# Out:
# ...
# Using device: cuda
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Image saved as fantasy_landscape.png
